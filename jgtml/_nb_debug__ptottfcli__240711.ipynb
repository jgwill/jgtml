# %% [markdown]
# # --@STCIssue jgtml/ptojgtmlttfprotocli.py

# %%
import ptottf

# %%
i="EUR/USD";t="D1"
use_fresh=False
from jgtutils.jgtconstants import MFI_SIGNAL,AO,AC,TEETH,JAW,LIPS,ZONE_SIGNAL
columns_list_from_higher_tf=[MFI_SIGNAL,AO,AC,TEETH,JAW,LIPS,ZONE_SIGNAL]
df=ptottf.create_ttf_csv(i,t,use_fresh=use_fresh,columns_list_from_higher_tf=columns_list_from_higher_tf)
# Out:
# Columns List from Higher TF: ['mfi_sig', 'ao', 'ac', 'teeth', 'jaw', 'lips', 'zone_sig']
#    CDSSvc Read:    CDSSvc Read:    CDSSvc Read:    EUR/USDEUR/USDEUR/USD         D1W1M1   ///   D1D1D1
#
#
#
#
#
#     TTF Output full:'/src/_jgt/data/ttf/EUR-USD_D1_ttf.csv'
#     TTF Output sel :'/src/_jgt/data/ttf/EUR-USD_D1_ttf_sel.csv'

# %%
df
# Out:
#                      BidOpen  BidHigh   BidLow  BidClose  AskOpen  AskHigh  \
# Date
# 2023-07-15 21:00:00  1.12251  1.12355  1.12240   1.12315  1.12341  1.12430
# 2023-07-16 21:00:00  1.12315  1.12488  1.12033   1.12314  1.12400  1.12491
# 2023-07-17 21:00:00  1.12314  1.12757  1.12087   1.12281  1.12376  1.12758
# 2023-07-18 21:00:00  1.12281  1.12400  1.11743   1.11972  1.12285  1.12403
# 2023-07-19 21:00:00  1.11972  1.12291  1.11184   1.11291  1.12034  1.12292
# ...                      ...      ...      ...       ...      ...      ...
# 2024-07-07 21:00:00  1.08004  1.08451  1.07991   1.08237  1.08061  1.08453
# 2024-07-08 21:00:00  1.08237  1.08334  1.08054   1.08135  1.08242  1.08335
# 2024-07-09 21:00:00  1.08135  1.08305  1.08103   1.08298  1.08139  1.08310
# 2024-07-10 21:00:00  1.08298  1.09000  1.08249   1.08676  1.08304  1.09003
# 2024-07-11 21:00:00  1.08676  1.08676  1.08645   1.08660  1.08685  1.08711
#
#                       AskLow  AskClose  Volume      Open  ...    jaw_M1  \
# Date                                                      ...
# 2023-07-15 21:00:00  1.12328   1.12400      54  1.122960  ...  1.091731
# 2023-07-16 21:00:00  1.12036   1.12376  180557  1.123575  ...  1.091731
# 2023-07-17 21:00:00  1.12089   1.12285  265251  1.123450  ...  1.091731
# 2023-07-18 21:00:00  1.11746   1.12034  253554  1.122830  ...  1.091731
# 2023-07-19 21:00:00  1.11186   1.11298  231875  1.120030  ...  1.091731
# ...                      ...       ...     ...       ...  ...       ...
# 2024-07-07 21:00:00  1.08054   1.08242  181809  1.080325  ...  1.083652
# 2024-07-08 21:00:00  1.08056   1.08139  163253  1.082395  ...  1.083652
# 2024-07-09 21:00:00  1.08109   1.08304  145258  1.081370  ...  1.083652
# 2024-07-10 21:00:00  1.08294   1.08685  235602  1.083010  ...  1.083652
# 2024-07-11 21:00:00  1.08678   1.08678      45  1.086805  ...  1.083652
#
#                       lips_M1  zone_sig_M1  mfi_sig_W1     ao_W1     ac_W1  \
# Date
# 2023-07-15 21:00:00  1.063864          0.0           3  0.312411  0.273403
# 2023-07-16 21:00:00  1.063864          0.0           3  0.312411  0.273403
# 2023-07-17 21:00:00  1.063864          0.0           3  0.312411  0.273403
# 2023-07-18 21:00:00  1.063864          0.0           3  0.312411  0.273403
# 2023-07-19 21:00:00  1.063864          0.0           3  0.312411  0.273403
# ...                       ...          ...         ...       ...       ...
# 2024-07-07 21:00:00  1.080552          0.0           2 -0.106637 -0.109421
# 2024-07-08 21:00:00  1.080552          0.0           2 -0.106637 -0.109421
# 2024-07-09 21:00:00  1.080552          0.0           2 -0.106637 -0.109421
# 2024-07-10 21:00:00  1.080552          0.0           2 -0.106637 -0.109421
# 2024-07-11 21:00:00  1.080552          0.0           2 -0.106637 -0.109421
#
#                      teeth_W1    jaw_W1   lips_W1  zone_sig_W1
# Date
# 2023-07-15 21:00:00   1.08043  1.073978  1.085477          1.0
# 2023-07-16 21:00:00   1.08043  1.073978  1.085477          1.0
# 2023-07-17 21:00:00   1.08043  1.073978  1.085477          1.0
# 2023-07-18 21:00:00   1.08043  1.073978  1.085477          1.0
# 2023-07-19 21:00:00   1.08043  1.073978  1.085477          1.0
# ...                       ...       ...       ...          ...
# 2024-07-07 21:00:00  1.080863  1.080105  1.078362          0.0
# 2024-07-08 21:00:00  1.080863  1.080105  1.078362          0.0
# 2024-07-09 21:00:00  1.080863  1.080105  1.078362          0.0
# 2024-07-10 21:00:00  1.080863  1.080105  1.078362          0.0
# 2024-07-11 21:00:00  1.080863  1.080105  1.078362          0.0
#
# [310 rows x 75 columns]

# %%
df.columns
# Out:
# Index(['BidOpen', 'BidHigh', 'BidLow', 'BidClose', 'AskOpen', 'AskHigh',
#        'AskLow', 'AskClose', 'Volume', 'Open', 'High', 'Low', 'Close',
#        'Median', 'ao', 'ac', 'jaw', 'teeth', 'lips', 'bjaw', 'bteeth', 'blips',
#        'tjaw', 'tteeth', 'tlips', 'fh', 'fl', 'fh3', 'fl3', 'fh5', 'fl5',
#        'fh8', 'fl8', 'fh13', 'fl13', 'fh21', 'fl21', 'fh34', 'fl34', 'fh55',
#        'fl55', 'fh89', 'fl89', 'mfi', 'fdbb', 'fdbs', 'fdb', 'aoaz', 'aobz',
#        'zlc', 'zlcb', 'zlcs', 'zone_sig', 'sz', 'bz', 'acs', 'acb', 'ss', 'sb',
#        'mfi_sig', 'mfi_str', 'mfi_sig_M1', 'ao_M1', 'ac_M1', 'teeth_M1',
#        'jaw_M1', 'lips_M1', 'zone_sig_M1', 'mfi_sig_W1', 'ao_W1', 'ac_W1',
#        'teeth_W1', 'jaw_W1', 'lips_W1', 'zone_sig_W1'],
#       dtype='object')

# %% [markdown]
# 'BidOpen', 'BidHigh', 'BidLow', 'BidClose', 'AskOpen', 'AskHigh',
#        'AskLow', 'AskClose', 'Volume', 'Open', 'High', 'Low', 'Close',
#        'Median', 'ao', 'ac', 'jaw', 'teeth', 'lips', 'bjaw', 'bteeth', 'blips',
#        'tjaw', 'tteeth', 'tlips', 'fh', 'fl', 'fh3', 'fl3', 'fh5', 'fl5',
#        'fh8', 'fl8', 'fh13', 'fl13', 'fh21', 'fl21', 'fh34', 'fl34', 'fh55',
#        'fl55', 'fh89', 'fl89', 'mfi', 'fdbb', 'fdbs', 'fdb', 'aoaz', 'aobz',
#        'zlc', 'zlcb', 'zlcs', 'zcol', 'zone_sig', 'sz', 'bz', 'acs', 'acb',
#        'ss', 'sb', 'price_peak_above', 'price_peak_bellow', 'ao_peak_above',
#        'ao_peak_bellow', 'mfi_sq', 'mfi_green', 'mfi_fade', 'mfi_fake',
#        'mfi_sig', 'mfi_str', 'mfi_sig_M1', 'zone_sig_M1', 'ao_M1',
#        'mfi_sig_W1', 'zone_sig_W1', 'ao_W1'

# %%
mfi_sig_type=int

# %%
print(mfi_sig_type)
# Out:
# <class 'int'>

# %%
myvar:mfi_sig_type=1.0

# %%
myvar
# Out:
# 1.0

# %%
mfi_sig_type(myvar)
# Out:
# 1
